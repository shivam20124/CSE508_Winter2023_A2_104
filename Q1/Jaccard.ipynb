# %%
import os

var = "/Users/shivam/Desktop/College/Sem 6/IR/CSE508_Winter2023_A2_104/Q1/Processed_Files"
file_names = os.listdir(var)

# %%
term_count = {}

len_file_names = len(file_names)

for i in range(len_file_names):
    read_filename = var + "/" + file_names[i]
    final_words_array = []
    
    with open(read_filename, 'r') as filehandler:
        for line_item in filehandler:
            curr_item = line_item[:-1]
            final_words_array.append(curr_item)
    exist = 0
    for j in range(len(final_words_array)):
        if final_words_array[j] not in term_count:
            term_count[final_words_array[j]] = 1
            exist = 1
        elif((final_words_array[j] in term_count) and (exist == 0)):
            term_count[final_words_array[j]]+=1

# %%
term_count
# Out:
# {'inviscid': 52,
#  'incompressible': 89,
#  'flow': 829,
#  'theory': 291,
#  'static': 59,
#  'two': 220,
#  'dimensional': 160,
#  'solid': 21,
#  'jets': 18,
#  'proximity': 3,
#  'ground': 21,
#  'impinging': 4,
#  'orthogonally': 1,
#  'presented': 142,
#  'using': 56,
#  'conformal': 2,
#  'mapping': 2,
#  'methods': 64,
#  'shown': 97,
#  'thrust': 15,
#  'jet': 152,
#  'constant': 67,
#  'power': 29,
#  'initially': 11,
#  'decreases': 2,
#  'approached': 3,
#  'magnitude': 16,
#  'effect': 152,
#  'regained': 1,
#  'low': 75,
#  'height': 16,
#  'to': 9,
#  'width': 5,
#  'ratio': 116,
#  'approximately': 21,
#  '0': 119,
#  '55': 5,
#  'maximuin': 1,
#  'decrease': 9,
#  '6': 57,
#  'percent': 16,
#  'thus': 11,
#  'largely': 3,
#  'unfavorable': 1,
#  'free': 161,
#  'flight': 77,
#  'measurements': 114,
#  'dynamic': 40,
#  'charts': 15,
#  'prepared': 1,
#  'relating': 9,
#  'thermodynamic': 16,
#  'properties': 59,
#  'air': 112,
#  'chemical': 20,
#  'equilibrium': 50,
#  'temperatures': 28,
#  '15': 22,
#  '000': 36,
#  'k': 18,
#  'pressures': 48,
#  '10': 42,
#  'atmospheres': 6,
#  'also': 71,
#  'included': 28,
#  'showing': 4,
#  'composition': 4,
#  'isentropic': 5,
#  'exponent': 1,
#  'speed': 94,
#  'sound': 13,
#  'based': 73,
#  'data': 93,
#  'calculated': 63,
#  'national': 4,
#  'bureau': 1,
#  'standards': 1,
#  'operation': 7,
#  'npl': 1,
#  '18in': 1,
#  'x': 36,
#  '14in': 1,
#  'wind': 81,
#  'tunnel': 112,
#  'transonic': 70,
#  'range': 89,
#  'brief': 12,
#  'description': 10,
#  'slotted': 3,
#  'liners': 1,
#  'used': 89,
#  'given': 150,
#  'together': 11,
#  'requirements': 6,
#  'surveys': 8,
#  'observations': 10,
#  'made': 176,
#  'wall': 104,
#  'interference': 34,
#  'half': 19,
#  'model': 73,
#  'swept': 23,
#  'wing': 206,
#  'tested': 17,
#  'ablation': 13,
#  'glassy': 1,
#  'materials': 12,
#  'around': 33,
#  'blunt': 103,
#  'bodies': 150,
#  'revolution': 77,
#  'steady': 73,
#  'state': 18,
#  'equations': 203,
#  'motion': 71,
#  'thin': 126,
#  'layer': 426,
#  'material': 9,
#  'surface': 193,
#  'ablating': 2,
#  'radiating': 1,
#  'body': 186,
#  'reduced': 26,
#  'first': 69,
#  'order': 95,
#  'ordinary': 11,
#  'differential': 46,
#  'equation': 91,
#  'integrated': 10,
#  'numerically': 13,
#  'solution': 160,
#  'coupled': 9,
#  'boundary': 491,
#  'laminar': 226,
#  'turbulent': 118,
#  'heat': 261,
#  'transfer': 212,
#  'without': 20,
#  'mass': 35,
#  'vaporization': 1,
#  'distribution': 157,
#  'effective': 9,
#  'energy': 40,
#  'obtained': 138,
#  'cone': 68,
#  'cylinder': 120,
#  'hemispherical': 3,
#  'cap': 2,
#  're': 12,
#  'enters': 1,
#  'atmosphere': 40,
#  'hypersonic': 201,
#  'speeds': 120,
#  'quartz': 2,
#  'found': 93,
#  'process': 15,
#  'heating': 39,
#  'efficient': 2,
#  'case': 92,
#  'increased': 15,
#  'stagnation': 106,
#  'point': 95,
#  'verified': 4,
#  'experiments': 38,
#  'present': 51,
#  'development': 19,
#  'permit': 3,
#  'use': 73,
#  'experimental': 162,
#  'investigations': 23,
#  'buckling': 125,
#  'sandwich': 14,
#  'normal': 44,
#  'pressure': 431,
#  'theoretical': 114,
#  'study': 92,
#  'sphere': 15,
#  'comprised': 2,
#  'core': 13,
#  'modulus': 4,
#  'facing': 6,
#  'layers': 57,
#  'higher': 18,
#  'resistance': 9,
#  'external': 41,
#  'linearized': 40,
#  'reducible': 3,
#  'classical': 19,
#  'monocoque': 2,
#  'spherical': 17,
#  'shells': 104,
#  'critical': 35,
#  'various': 60,
#  'radius': 13,
#  'thickness': 76,
#  'ratios': 33,
#  'strong': 17,
#  'viscous': 98,
#  'interaction': 54,
#  'flat': 148,
#  'plate': 179,
#  'report': 40,
#  'gives': 23,
#  'account': 24,
#  'approximate': 89,
#  'problem': 143,
#  'disturbance': 14,
#  'region': 68,
#  'divided': 3,
#  'regions': 14,
#  'small': 79,
#  'perturbation': 12,
#  'applied': 50,
#  'method': 279,
#  'similar': 41,
#  'solutions': 115,
#  'compressible': 108,
#  'treatment': 13,
#  'law': 33,
#  'derived': 66,
#  'velocity': 159,
#  'matched': 2,
#  'formulas': 19,
#  'induced': 39,
#  'skin': 73,
#  'friction': 63,
#  'coefficient': 47,
#  'numerical': 81,
#  'results': 230,
#  'significance': 8,
#  'discussed': 53,
#  'future': 3,
#  'improvements': 3,
#  'indicated': 16,
#  'generation': 3,
#  'aerodynamic': 124,
#  'means': 37,
#  'summary': 8,
#  'important': 22,
#  'noise': 32,
#  'radiated': 1,
#  'cold': 5,
#  'subsonic': 73,
#  'related': 15,
#  'predictions': 10,
#  'lighthill': 7,
#  's': 79,
#  'general': 92,
#  'new': 41,
#  'test': 51,
#  'techniques': 19,
#  'hypervelocity': 7,
#  'measurement': 7,
#  'rocket': 19,
#  'exhaust': 11,
#  'effects': 197,
#  'vehicle': 14,
#  'stability': 92,
#  'damping': 13,
#  'arc': 3,
#  'discharge': 6,
#  'type': 55,
#  'sample': 3,
#  'indicate': 25,
#  'quality': 1,
#  'obtainable': 2,
#  'samples': 1,
#  'self': 7,
#  'luminous': 2,
#  'shadowgraph': 3,
#  'photographs': 5,
#  'cylindrical': 89,
#  'conical': 66,
#  'circular': 111,
#  'cross': 32,
#  'section': 54,
#  'simultaneous': 9,
#  'action': 2,
#  'axial': 77,
#  'compression': 37,
#  'consider': 5,
#  'determination': 31,
#  'upper': 17,
#  'limit': 9,
#  'loads': 42,
#  'compressive': 15,
#  'force': 49,
#  'uniformly': 16,
#  'distributed': 16,
#  'plane': 49,
#  'sections': 19,
#  'isotropic': 5,
#  'starting': 4,
#  'neutral': 5,
#  'ref': 6,
#  '1': 136,
#  'torsion': 13,
#  '2': 88,
#  'upon': 29,
#  'possible': 24,
#  'satisfy': 2,
#  'conditions': 100,
#  'contrast': 2,
#  '3': 59,
#  'attention': 11,
#  'paid': 2,
#  'fulfillment': 1,
#  '4': 42,
#  'part': 40,
#  'satisfied': 4,
#  'according': 7,
#  'galerkin': 2,
#  'longitudinal': 24,
#  'let': 2,
#  'us': 2,
#  'note': 55,
#  'suggested': 9,
#  'reference': 12,
#  '5': 63,
#  'well': 39,
#  'founded': 1,
#  'may': 51,
#  'lead': 8,
#  'number': 287,
#  'cases': 37,
#  'substantial': 5,
#  'mistake': 1,
#  'load': 34,
#  'confluent': 1,
#  'hypergeometric': 1,
#  'function': 58,
#  'functions': 23,
#  'proved': 1,
#  'useful': 9,
#  'many': 17,
#  'branches': 2,
#  'physics': 3,
#  'problems': 74,
#  'involving': 8,
#  'diffusion': 20,
#  'sedimentation': 1,
#  'isotope': 1,
#  'separation': 64,
#  'protein': 1,
#  'molecular': 7,
#  'weight': 11,
#  'determinations': 1,
#  'ultracentrifuge': 1,
#  'electrons': 2,
#  'high': 132,
#  'frequency': 19,
#  'gas': 100,
#  'discharges': 1,
#  'frequently': 1,
#  'expressed': 11,
#  'terms': 43,
#  'breakdown': 2,
#  'electric': 1,
#  'field': 95,
#  'predicted': 16,
#  'theoretically': 11,
#  'gases': 20,
#  'kinetic': 7,
#  'presents': 27,
#  'six': 4,
#  'figure': 1,
#  'tables': 16,
#  'behaviour': 18,
#  'non': 40,
#  'linear': 44,
#  'systems': 9,
#  'phenomena': 16,
#  'occur': 9,
#  'world': 1,
#  'governed': 2,
#  'nonlinear': 29,
#  'relationships': 2,
#  'mathematical': 9,
#  'sciences': 1,
#  'difficulties': 3,
#  'analysis': 164,
#  'hindered': 1,
#  'formulation': 12,
#  'concepts': 11,
#  'would': 11,
#  'understand': 1,
#  'article': 5,
#  'progress': 4,
#  'understanding': 6,
#  'behavior': 21,
#  'reviewed': 8,
#  'attempt': 10,
#  'resulting': 17,
#  'way': 9,
#  'generality': 2,
#  'approximations': 24,
#  'transport': 9,
#  'temperature': 162,
#  'closed': 11,
#  'form': 68,
#  'partition': 1,
#  'major': 16,
#  'components': 13,
#  'neglecting': 4,
#  'minor': 6,
#  'compressibility': 15,
#  'enthalpy': 13,
#  'entropy': 9,
#  'specific': 12,
#  'heats': 5,
#  'coefficients': 55,
#  'viscosity': 32,
#  'thermal': 53,
#  'conductivity': 9,
#  'prandtl': 25,
#  'numbers': 131,
#  'tabulated': 7,
#  '500degree': 1,
#  '000degree': 1,
#  '0001': 1,
#  '100': 6,
#  'mol': 1,
#  'fractions': 1,
#  'values': 52,
#  'fully': 10,
#  'ionized': 6,
#  'complete': 14,
#  'become': 7,
#  'compared': 55,
#  'unity': 13,
#  'transparent': 1,
#  'flux': 7,
#  'investigation': 174,
#  'mach': 285,
#  'stress': 66,
#  'flutter': 103,
#  'characteristics': 101,
#  'single': 21,
#  'bay': 2,
#  'panels': 29,
#  'length': 34,
#  '96': 3,
#  'stiffener': 8,
#  'ranging': 8,
#  '500': 4,
#  '300': 3,
#  'f': 12,
#  'panel': 37,
#  'supporting': 4,
#  'structure': 31,
#  'allowed': 2,
#  'partial': 10,
#  'expansion': 23,
#  'skins': 2,
#  'lateral': 14,
#  'directions': 2,
#  'varied': 15,
#  'faired': 1,
#  'points': 11,
#  'consisted': 3,
#  'portion': 15,
#  'buckled': 13,
#  'transition': 71,
#  'intersection': 2,
#  'boundaries': 10,
#  'susceptible': 1,
#  'fairly': 5,
#  'distinct': 3,
#  'large': 81,
#  'amplitude': 5,
#  'show': 26,
#  'increase': 26,
#  'trend': 2,
#  'reversed': 3,
#  'modified': 26,
#  'parameter': 25,
#  'accounts': 1,
#  'variations': 17,
#  'scatter': 2,
#  'resulted': 2,
#  'neglected': 7,
#  'exact': 40,
#  'clamped': 21,
#  'condition': 25,
#  'zero': 74,
#  'midplane': 4,
#  'addition': 10,
#  'twomode': 1,
#  'transtability': 2,
#  'experimentally': 21,
#  'determined': 52,
#  'generalized': 10,
#  'graphs': 3,
#  'utilizing': 8,
#  'research': 18,
#  'previously': 20,
#  'reported': 7,
#  'radiative': 4,
#  'dissociated': 15,
#  'calculating': 35,
#  'determining': 24,
#  'momentum': 20,
#  'reynolds': 103,
#  'distributions': 97,
#  'axisymmetric': 42,
#  'correlations': 2,
#  'valid': 20,
#  'velocities': 23,
#  '6000': 1,
#  '26': 4,
#  'fps': 2,
#  'altitudes': 8,
#  '250': 2,
#  'ft': 21,
#  'covers': 1,
#  'entry': 23,
#  'regime': 7,
#  'practical': 16,
#  'trajectories': 4,
#  'interest': 17,
#  'today': 1,
#  'last': 3,
#  'specialized': 1,
#  'icbm': 1,
#  'nose': 63,
#  'applications': 11,
#  'making': 9,
#  'rapid': 14,
#  'engineering': 4,
#  'estimates': 10,
#  'preliminary': 10,
#  'design': 62,
#  'evaluations': 1,
#  'associated': 21,
#  'earth': 7,
#  'aircraft': 41,
#  'paper': 104,
#  'deals': 11,
#  'aerodynamics': 10,
#  'shapes': 36,
#  'kuchemann': 1,
#  'second': 53,
#  'international': 2,
#  'congress': 1,
#  'aeronautical': 3,
#  'zurich': 1,
#  '1960': 1,
#  'suitable': 15,
#  'achieving': 1,
#  'required': 20,
#  'supersonic': 276,
#  'namely': 3,
#  'wingbody': 2,
#  'arrangements': 5,
#  'sweepback': 7,
#  'angles': 44,
#  '55degrees': 1,
#  '60degrees': 1,
#  'streamwise': 10,
#  'chord': 14,
#  'per': 29,
#  'cent': 8,
#  'slender': 103,
#  'near': 45,
#  'triangular': 8,
#  'wings': 137,
#  'sharp': 28,
#  'leading': 83,
#  'edges': 38,
#  'slewed': 1,
#  'powered': 3,
#  'lift': 116,
#  'variable': 17,
#  'geometry': 12,
#  'dealing': 6,
#  'briefly': 6,
#  'need': 6,
#  'avoiding': 1,
#  'edge': 97,
#  'demonstrated': 9,
#  'conclusion': 4,
#  'desirable': 2,
#  'flaps': 5,
#  'blowing': 3,
#  'suction': 19,
#  'knee': 1,
#  'blown': 1,
#  'trailing': 24,
#  'tests': 82,
#  'described': 37,
#  'simplified': 20,
#  'control': 33,
#  'mention': 1,
#  'possibility': 10,
#  'adverse': 13,
#  'maximum': 25,
#  'involves': 6,
#  'steadiness': 1,
#  'therefore': 10,
#  'view': 13,
#  'buffeting': 2,
#  'plan': 8,
#  'pitch': 10,
#  'up': 4,
#  'analysed': 5,
#  'short': 22,
#  'available': 18,
#  'rolling': 17,
#  'moments': 13,
#  'due': 54,
#  'sideslip': 6,
#  'give': 10,
#  'rise': 16,
#  'serious': 1,
#  'knowledge': 10,
#  'directional': 1,
#  'yawing': 6,
#  'rotary': 2,
#  'derivatives': 45,
#  'finally': 4,
#  'summarised': 2,
#  'concerned': 21,
#  'work': 27,
#  'aimed': 1,
#  'clarifying': 1,
#  'handling': 1,
#  'qualities': 1,
#  'much': 7,
#  'forecasts': 1,
#  'pilot': 1,
#  'wants': 1,
#  'aspects': 12,
#  'vertical': 30,
#  'detail': 13,
#  'glide': 3,
#  'path': 6,
#  'holding': 1,
#  'avro': 1,
#  '707a': 1,
#  'artificially': 3,
#  'worsened': 1,
#  'substantially': 4,
#  'performance': 28,
#  'piloting': 1,
#  'task': 1,
#  'achieved': 6,
#  'expense': 1,
#  'effort': 2,
#  'tentative': 1,
#  'conclusions': 7,
#  'levels': 7,
#  'phugoid': 1,
#  'are': 2,
#  'nevertheless': 1,
#  'drawn': 4,
#  'review': 20,
#  'status': 4,
#  'mainly': 5,
#  'american': 1,
#  'principles': 6,
#  'creep': 42,
#  'strength': 31,
#  'relation': 21,
#  'time': 49,
#  'dependent': 19,
#  'tangent': 10,
#  'as': 2,
#  'conceived': 1,
#  'shanley': 1,
#  'actual': 6,
#  'column': 12,
#  'capacity': 3,
#  'clarified': 1,
#  'interpreted': 3,
#  'limiting': 7,
#  'conservative': 1,
#  'estimate': 7,
#  'tangentmodulus': 1,
#  'is': 13,
#  'approximation': 41,
#  'however': 13,
#  'either': 22,
#  'nonconservative': 1,
#  'imperfect': 4,
#  'real': 22,
#  'columns': 28,
#  'typical': 12,
#  'alloys': 2,
#  'cited': 1,
#  'plk': 1,
#  'detailed': 7,
#  'portious': 1,
#  'asymmetric': 5,
#  'configurations': 23,
#  'requires': 2,
#  'successive': 4,
#  'carried': 24,
#  'systematic': 7,
#  'fashion': 1,
#  'appropriate': 9,
#  'convergent': 11,
#  'procedure': 24,
#  'producing': 3,
#  'successively': 2,
#  'refined': 4,
#  'sets': 5,
#  'initial': 36,
#  'direct': 13,
#  'inverse': 5,
#  'formulated': 5,
#  'following': 10,
#  'reasonable': 6,
#  'shock': 222,
#  'shape': 58,
#  'one': 84,
#  'determine': 41,
#  'desired': 2,
#  'degree': 16,
#  'approach': 20,
#  'qm': 1,
#  'developed': 82,
#  'stretching': 3,
#  'coordinates': 11,
#  'spirit': 1,
#  'poincare': 1,
#  'kuo': 1,
#  'transformed': 9,
#  'along': 53,
#  'intermediate': 7,
#  'lines': 4,
#  'annul': 1,
#  'perturbations': 2,
#  'local': 47,
#  'resultant': 3,
#  'b': 5,
#  'integral': 43,
#  'coordinate': 7,
#  'strip': 7,
#  'shifted': 1,
#  'component': 4,
#  'determines': 1,
#  'justified': 3,
#  'governing': 13,
#  'consideration': 18,
#  'validity': 8,
#  'proposed': 17,
#  'assessed': 2,
#  'application': 42,
#  'comparison': 45,
#  'experiment': 26,
#  'disk': 9,
#  'set': 25,
#  'termperature': 1,
#  'stream': 159,
#  '76': 3,
#  'highly': 16,
#  'configuration': 19,
#  '8': 38,
#  'blunted': 18,
#  'ogive': 10,
#  'flared': 2,
#  'afterbody': 13,
#  '30': 10,
#  '85': 5,
#  'tip': 8,
#  '20': 14,
#  '23': 2,
#  'histories': 4,
#  'plots': 2,
#  'moment': 22,
#  'center': 13,
#  'curve': 11,
#  'slope': 16,
#  'of': 14,
#  'gravity': 4,
#  'location': 16,
#  'models': 39,
#  'statically': 3,
#  'dynamically': 2,
#  'stable': 7,
#  'throughout': 8,
#  'average': 12,
#  'moved': 1,
#  'slightly': 12,
#  'forward': 22,
#  'decreasing': 3,
#  'remained': 2,
#  'practically': 2,
#  'rising': 1,
#  'noted': 4,
#  'drag': 92,
#  'base': 64,
#  'area': 11,
#  'roughness': 25,
#  'insects': 1,
#  'observed': 14,
#  'past': 88,
#  'airfoils': 25,
#  'advances': 8,
#  'maintenance': 1,
#  'extensive': 4,
#  'artificial': 3,
#  'irregularities': 1,
#  'rivet': 1,
#  'heads': 1,
#  'lap': 1,
#  'joints': 3,
#  'window': 1,
#  'etc': 4,
#  'kind': 1,
#  'generated': 11,
#  'impact': 11,
#  'natural': 10,
#  'roughening': 1,
#  'though': 2,
#  'investigated': 55,
#  'subject': 16,
#  'phenomenon': 7,
#  'parts': 8,
#  'fruit': 1,
#  'fly': 1,
#  'drosophila': 1,
#  'common': 3,
#  'housefly': 1,
#  'former': 2,
#  'treated': 16,
#  'mathematically': 3,
#  'separate': 3,
#  'yet': 3,
#  'published': 9,
#  'agreement': 40,
#  'satisfactory': 11,
#  'essentials': 1,
#  'profile': 31,
#  'consist': 3,
#  'principally': 1,
#  'pronounced': 1,
#  'peak': 4,
#  'followed': 4,
#  'gradually': 1,
#  'diminishing': 1,
#  'value': 42,
#  'excrescence': 1,
#  'further': 2,
#  'that': 17,
#  'severe': 3,
#  'eliminated': 2,
#  'downstream': 24,
#  'causes': 4,
#  'passage': 2,
#  'i': 22,
#  'e': 28,
#  'roughened': 1,
#  'aerodynamically': 4,
#  'smooth': 11,
#  'moreover': 2,
#  'appears': 9,
#  'defining': 3,
#  'upstream': 9,
#  'insignificant': 1,
#  'fundamentally': 1,
#  'three': 69,
#  'character': 7,
#  'variational': 19,
#  'theorem': 6,
#  'undergoing': 3,
#  'plates': 72,
#  'beams': 4,
#  'calculus': 2,
#  'conjunction': 9,
#  'stated': 4,
#  'illustrated': 9,
#  'axially': 33,
#  'symmetrical': 16,
#  'nozzles': 29,
#  'expansions': 5,
#  'powers': 4,
#  'r': 20,
#  'curvature': 31,
#  'nozzle': 62,
#  'throat': 7,
#  'measured': 42,
#  'heights': 1,
#  'divergent': 5,
#  'series': 44,
#  'symmetric': 41,
#  'accuracy': 22,
#  'confirmed': 3,
#  'known': 30,
#  'branchline': 1,
#  'concerning': 10,
#  'assumed': 45,
#  'proportional': 8,
#  'absolute': 5,
#  'these': 1,
#  'assumptions': 21,
#  'empirical': 12,
#  'relations': 13,
#  'cope': 1,
#  'transformation': 19,
#  'ordinate': 6,
#  'multiplicative': 1,
#  'factor': 15,
#  'g': 6,
#  'term': 6,
#  'greater': 18,
#  'tends': 4,
#  'outside': 9,
#  'several': 52,
#  'particular': 35,
#  'considered': 80,
#  'including': 34,
#  'accelerated': 2,
#  'linearly': 9,
#  'increasing': 19,
#  'retarded': 2,
#  'implications': 3,
#  'qualitative': 4,
#  'mainstream': 5,
#  'starts': 1,
#  'rises': 1,
#  'subsequently': 3,
#  'falls': 1,
#  'concluded': 9,
#  'reduce': 8,
#  'cause': 9,
#  'earlier': 5,
#  'kinematic': 3,
#  'corresponding': 32,
#  'transverse': 52,
#  'potential': 25,
#  'fluid': 132,
#  'axis': 26,
#  'right': 5,
#  'perpendicular': 11,
#  'meridians': 1,
#  'vary': 5,
#  'azimuthal': 2,
#  'angle': 96,
#  'round': 12,
#  'simple': 83,
#  'manner': 15,
#  'entirely': 1,
#  'elementary': 2,
#  'considerations': 12,
#  'influence': 44,
#  'wave': 109,
#  'bring': 3,
#  'importance': 10,
#  'semi': 23,
#  'infinite': 36,
#  'insulated': 14,
#  'approximated': 6,
#  'streamlines': 4,
#  'enter': 2,
#  'crossed': 2,
#  'curved': 21,
#  'consequently': 1,
#  'outer': 23,
#  'appreciably': 2,
#  'vorticity': 21,
#  'larger': 12,
#  'usual': 9,
#  'errors': 1,
#  'within': 27,
#  'framework': 5,
#  'appreciable': 2,
#  'plotted': 7,
#  'closely': 6,
#  'approaches': 5,
#  'hammitt': 1,
#  'bogdonoff': 1,
#  'helium': 28,
#  'careful': 1,
#  'creepbuckling': 1,
#  'bending': 60,
#  'slenderness': 2,
#  '111': 1,
#  'performed': 14,
#  '600': 4,
#  'strain': 13,
#  'taken': 20,
#  'gages': 1,
#  'appendix': 1,
#  'rapidly': 8,
#  'deviation': 6,
#  'straightness': 2,
#  'rate': 43,
#  'latter': 8,
#  'develop': 6,
#  'semiempirical': 5,
#  'formula': 20,
#  'guide': 3,
#  'program': 5,
#  '18': 4,
#  'in': 17,
#  '20in': 1,
#  'propulsion': 8,
#  'laboratory': 7,
#  'sand': 1,
#  ...}

# %%
#Jaccard Co-Efficient as Binary
import pandas as pd
import numpy as np

def jaccard_coef(query_vector):
    df = pd.read_csv('binary_tf_idf.csv')
    jaccard_coeff_dict = {}
    for i in range(1400):
        row_list = df.loc[i, :].values.flatten().tolist()
        intersection = np.logical_and(query_vector, row_list)
        union = np.logical_or(query_vector, row_list)
        coef = intersection.sum()/float(union.sum())
        jaccard_coeff_dict[i+1] = coef
    return jaccard_coeff_dict

# %%
#Binary Query Vector

def bin_query_vector(query):
    query_vector = [0]*7632
    len_query = len(query)
    for i in range(len_query):
        if query[i] in term_count:
            index = list(term_count).index(query[i])
            query_vector[index] = 1
    return query_vector

# %%
import nltk
nltk.download('stopwords')
# !pip install --user -U nltk
from nltk.corpus import stopwords
en_stopwords = stopwords.words('english')
# Out:
# zsh:1: command not found: pip
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shivam/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
import numpy as np
import re
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
import matplotlib
from nltk.tokenize import TweetTokenizer
import matplotlib.pyplot as plt
import nltk
import nltk.data
import seaborn as sns
from nltk.tokenize import sent_tokenize
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shivam/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocessing(text):
    # text=text[0:100]
    #Lowercasing the text
    lower=text.lower()

    #Splitting into tokens
    tokens=lower.split()

    #Removing stop words
    without_stop = []
    for tok in tokens:
        if tok not in en_stopwords:
            without_stop.append(tok)

    #Removing Punctuations and Blank Space tokens
    tokenizer = RegexpTokenizer(r"\w+")
    final=tokenizer.tokenize(' '.join(without_stop))

    return final

# %%
def query_input():
    print("Please enter your query:")
    query1 = input()
    query = preprocessing(query1)
    return query

# %%
from operator import itemgetter


def find_top10(coef_dict):
    N = 10
    print("The original dictionary is : " + str(coef_dict))
    res = dict(sorted(coef_dict.items(), key = itemgetter(1), reverse = True)[:N])
    print("The top 10 value pairs are  " + str(res))
    return res

# %%
q = query_input()
query_v = bin_query_vector(q)
j_c = jaccard_coef(query_v)
top10_j_c = find_top10(j_c)
# Out:
# Please enter your query:
# The original dictionary is : {1: 0.03278688524590164, 2: 0.028169014084507043, 3: 0.13333333333333333, 4: 0.05714285714285714, 5: 0.0, 6: 0.02, 7: 0.00980392156862745, 8: 0.0, 9: 0.017094017094017096, 10: 0.04, 11: 0.0, 12: 0.0, 13: 0.017543859649122806, 14: 0.005376344086021506, 15: 0.015873015873015872, 16: 0.030303030303030304, 17: 0.03125, 18: 0.020833333333333332, 19: 0.02564102564102564, 20: 0.013333333333333334, 21: 0.03333333333333333, 22: 0.018518518518518517, 23: 0.038461538461538464, 24: 0.020833333333333332, 25: 0.012903225806451613, 26: 0.07407407407407407, 27: 0.03508771929824561, 28: 0.03278688524590164, 29: 0.0, 30: 0.016666666666666666, 31: 0.0, 32: 0.0, 33: 0.008264462809917356, 34: 0.0125, 35: 0.030303030303030304, 36: 0.027777777777777776, 37: 0.030303030303030304, 38: 0.02631578947368421, 39: 0.016666666666666666, 40: 0.0, 41: 0.0, 42: 0.009174311926605505, 43: 0.0, 44: 0.014598540145985401, 45: 0.015873015873015872, 46: 0.0, 47: 0.0, 48: 0.0196078431372549, 49: 0.014084507042253521, 50: 0.013513513513513514, 51: 0.030303030303030304, 52: 0.02631578947368421, 53: 0.012195121951219513, 54: 0.01098901098901099, 55: 0.017241379310344827, 56: 0.012658227848101266, 57: 0.015151515151515152, 58: 0.025974025974025976, 59: 0.010309278350515464, 60: 0.014492753623188406, 61: 0.023809523809523808, 62: 0.0, 63: 0.014925373134328358, 64: 0.019230769230769232, 65: 0.0, 66: 0.0, 67: 0.0, 68: 0.0, 69: 0.015873015873015872, 70: 0.013333333333333334, 71: 0.0, 72: 0.01, 73: 0.023809523809523808, 74: 0.02127659574468085, 75: 0.0, 76: 0.0, 77: 0.0, 78: 0.0, 79: 0.014705882352941176, 80: 0.0, 81: 0.037037037037037035, 82: 0.0, 83: 0.0, 84: 0.012658227848101266, 85: 0.007936507936507936, 86: 0.05357142857142857, 87: 0.03508771929824561, 88: 0.015625, 89: 0.006172839506172839, 90: 0.0, 91: 0.014925373134328358, 92: 0.0, 93: 0.018518518518518517, 94: 0.013333333333333334, 95: 0.0, 96: 0.0125, 97: 0.020618556701030927, 98: 0.030303030303030304, 99: 0.008547008547008548, 100: 0.0, 101: 0.0, 102: 0.023809523809523808, 103: 0.03571428571428571, 104: 0.0, 105: 0.028985507246376812, 106: 0.06451612903225806, 107: 0.05128205128205128, 108: 0.018867924528301886, 109: 0.02702702702702703, 110: 0.0196078431372549, 111: 0.023255813953488372, 112: 0.015151515151515152, 113: 0.0, 114: 0.0, 115: 0.011764705882352941, 116: 0.014705882352941176, 117: 0.03225806451612903, 118: 0.014084507042253521, 119: 0.04878048780487805, 120: 0.02127659574468085, 121: 0.031746031746031744, 122: 0.02247191011235955, 123: 0.01020408163265306, 124: 0.023255813953488372, 125: 0.023255813953488372, 126: 0.015151515151515152, 127: 0.0, 128: 0.023255813953488372, 129: 0.00909090909090909, 130: 0.0, 131: 0.017699115044247787, 132: 0.015873015873015872, 133: 0.028169014084507043, 134: 0.027777777777777776, 135: 0.046153846153846156, 136: 0.0, 137: 0.041666666666666664, 138: 0.010869565217391304, 139: 0.0, 140: 0.0, 141: 0.0, 142: 0.0, 143: 0.0, 144: 0.01639344262295082, 145: 0.018518518518518517, 146: 0.020618556701030927, 147: 0.02631578947368421, 148: 0.03225806451612903, 149: 0.017391304347826087, 150: 0.013513513513513514, 151: 0.0, 152: 0.023529411764705882, 153: 0.04, 154: 0.0, 155: 0.011235955056179775, 156: 0.0, 157: 0.011111111111111112, 158: 0.0, 159: 0.0196078431372549, 160: 0.015625, 161: 0.02631578947368421, 162: 0.0, 163: 0.0, 164: 0.0, 165: 0.015503875968992248, 166: 0.01282051282051282, 167: 0.03389830508474576, 168: 0.009900990099009901, 169: 0.03125, 170: 0.022727272727272728, 171: 0.012195121951219513, 172: 0.0, 173: 0.008849557522123894, 174: 0.010752688172043012, 175: 0.030303030303030304, 176: 0.044444444444444446, 177: 0.010869565217391304, 178: 0.0, 179: 0.020618556701030927, 180: 0.08333333333333333, 181: 0.0, 182: 0.01694915254237288, 183: 0.03225806451612903, 184: 0.013888888888888888, 185: 0.0, 186: 0.011363636363636364, 187: 0.014705882352941176, 188: 0.023255813953488372, 189: 0.00980392156862745, 190: 0.0136986301369863, 191: 0.0357142857 ...
# The top 10 value pairs are  {3: 0.13333333333333333, 507: 0.13333333333333333, 382: 0.1, 242: 0.0967741935483871, 1141: 0.09375, 920: 0.08695652173913043, 180: 0.08333333333333333, 389: 0.08333333333333333, 298: 0.08, 241: 0.07894736842105263}
